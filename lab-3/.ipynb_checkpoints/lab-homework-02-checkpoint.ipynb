# %% [markdown]
# <h1 align='center'> COMP2420/COMP6420 - Introduction to Data Management, Analysis and Security</h1>
#
# <h2 align='center'> Homework Assessment 02</h2>
#
# *****
#
# Another week, another set of questions! Woohoo! The following set of **4 questions** test your understanding of the lecture and lab material taught during the lectures and the lab exercises in **Weeks 3 & 4**. In the **next lab (Lab 04)**, you'll be asked to complete any one of these exercises by your tutor in **Exam Mode**. Upon completion, you'll be marked by your tutor, based on the correctness and completeness of your solution.

# %%
# RUN THIS CELL TO IMPORT THE REQUIRED MODULES
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn')

# %% [markdown]
# ### Exercise 1 - Big Money Cars
#
# Extending upon our love for cars (especially the pricey ones!), we decided to have a look at the top 5 car manufacturers from the cars dataset. From the below dataset, help us return a dataset comprising of the **top 5 car manufacturers (in descending order)** along with their **average car prices**. But wait, there's a catch! You only have to do these computations on a subset of the dataset that only contains cars with the body-style `sedan` or `convertible`. Your result should look something like this -
#
# |    _     | company       | price     |
# | -------- |:-------------:| ---------:|
# |    6     | car_firm 1    |  1000.000 |
# |    8     | car_firm 2    |   980.000 |
# |   11     | car_firm 3    |   774.333 |
# |    3     | car_firm 4    |   645.000 |
# |    1     | car_firm 5    |   510.666 |

# %%
# TODO: COMPLETE THE BELOW FUNCTION
def top_5_pricey(df_cars):
    
    df_bodystyle=df_cars[(df_cars['body-style']=='sedan')|(df_cars['body-style']=='convertible')]
    df_bodystyle=df_bodystyle.groupby('company',as_index=False).mean().round(3)
    df_price=df_bodystyle.sort_values(by=['price'],ascending=False)
    result=df_price.loc[:,['company','price']].head()
    
    return result

# %%
# RUN THIS BLOCK TO TEST YOUR CODE
df_cars = pd.read_csv('automobile.csv')
top_5_pricey(df_cars)
# Out:
#           company      price
# 11        porsche  37028.000
# 6          jaguar  34600.000
# 8   mercedes-benz  33256.000
# 2             bmw  27213.333
# 7           mazda  18344.000

# %% [markdown]
# ### Exercise 2 - Gotta Catch 'Em All
#
# Now that we've got you motivated to attempt this question with the title itself, let's get on with it! You've been given a dataset with all the defining characteristics of pokémons (a.k.a **Pokédex**). You need to find the pokémon (and its HP) that has the highest HP (Hit Points) for each Type (`Type 1` and `Type 2` both). Because let's face it, that is an important data science question if you need to catch 'em all! :)

# %%
# TODO: COMPLETE THE BELOW FUNCTION
def poke_max_hp(df_pokemon):
    
    df_pokemons=df_pokemon.fillna('no').sort_values('HP',ascending=False).groupby(['Type 1','Type 2']).first()
    #df_pokemons=df_pokemon.fillna('no').groupby(['Type 1','Type 2'])['HP'].transform(max)==df_pokemon['HP']
    
    #df_pokemon=df_pokemon.fillna('no').groupby(['Type 1','Type 2']).agg(['HP':'max'])
    return df_pokemons

# %%
# RUN THIS BLOCK TO TEST YOUR CODE
df_pokemon = pd.read_csv('pokemon.csv')
poke_max_hp(df_pokemon)
# Out:
#                      #                     Name  Total   HP  Attack  Defense  \
# Type 1   Type 2
# Bug      Electric  596               Galvantula    472   70      77       60
#          Fighting  214  HeracrossMega Heracross    600   80     185      115
#          Fire      637                Volcarona    550   85      60       65
#          Flying    469                  Yanmega    515   86      76       86
#          Ghost     292                 Shedinja    236    1      90       45
#          Grass     542                 Leavanny    500   75     103       80
#          Ground    413      WormadamSandy Cloak    424   60      79      105
#          Poison     49                 Venomoth    450   70      65       60
#          Rock      558                  Crustle    475   70      95      125
#          Steel     205               Forretress    465   75      90      140
#          Water     283                  Surskit    269   40      30       32
#          no        617                 Accelgor    495   80      70       40
# Dark     Dragon    635                Hydreigon    600   92     105       90
#          Fighting  560                  Scrafty    488   65      90      115
#          Fire      229                 Houndoom    500   75      90       50
#          Flying    717                  Yveltal    680  126     131       95
#          Ghost     302                  Sableye    380   50      75       75
#          Ice       461                  Weavile    510   70     120       65
#          Psychic   687                  Malamar    482   86      92       88
#          Steel     625                  Bisharp    490   65     125      100
#          no        197                  Umbreon    525   95      65      110
# Dragon   Electric  644                   Zekrom    680  100     150      120
#          Fairy     334      AltariaMega Altaria    590   75     110      110
#          Fire      643                 Reshiram    680  100     120      100
#          Flying    384    RayquazaMega Rayquaza    780  105     180      100
#          Ground    445    GarchompMega Garchomp    700  108     170      115
#          Ice       646                   Kyurem    660  125     130       90
#          Psychic   381                   Latios    600   80      90       80
#          no        706                   Goodra    600   90     100       70
# Electric Dragon    181    AmpharosMega Ampharos    610   90      95      105
# ...                ...                      ...    ...  ...     ...      ...
# Rock     Ground     76                    Golem    495   80     120      130
#          Ice       699                  Aurorus    521  123      77       72
#          Psychic   337                 Lunatone    440   70      55       65
#          Steel     476                Probopass    525   60      55      145
#          Water     689               Barbaracle    500   72     105      115
#          no        409                Rampardos    495   97     165       60
# Steel    Dragon    483                   Dialga    680  100     120      120
#          Fairy     707                   Klefki    470   57      80       91
#          Fighting  638                 Cobalion    580   91      90      129
#          Flying    227                 Skarmory    465   65      80      140
#          Ghost     681    AegislashShield Forme    520   60      50      150
#          Ground    208                  Steelix    510   75      85      200
#          Psychic   385                  Jirachi    600  100     100      100
#          Rock      306                   Aggron    530   70     110      180
#          no        379                Registeel    580   80      75      150
# Water    Dark      130    GyaradosMega Gyarados    640   95     155      109
#          Dragon    484                   Palkia    680   90     120      100
#          Electric  171                  Lanturn    460  125      58       58
#          Fairy     184                Azumarill    420  100      50       80
#          Fighting  647     KeldeoResolute Forme    580   91      72       90
#          Flying    130                 Gyarados    540   95     125       79
#          Ghost     593                Jellicent    480  100      60       70
#          Grass     272                 Ludicolo    480   80      70       70
#          Ground    423                Gastrodon    475  111      83       68
#          Ice       131                   Lapras    535  130      85       80
#          Poison     73               Tentacruel    515   80      70       65
#          Psychic   199                 Slowking    490   95      75       80
#          Rock      369                Relicanth    485  100      90      130
#          Steel     395                 Empoleon    530   84      86       88
#          no        321                  Wailord    500  170      90       45
#
#                    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1   Type 2
# Bug      Electric       97       60    108           5      False
#          Fighting       40      105     75           2      False
#          Fire          135      105    100           5      False
#          Flying        116       56     95           4      False
#          Ghost          30       30     40           3      False
#          Grass          70       80     92           5      False
#          Ground         59       85     36           4      False
#          Poison         90       75     90           1      False
#          Rock           65       75     45           5      False
#          Steel          60       60     40           2      False
#          Water          50       52     65           3      False
#          no            100       60    145           5      False
# Dark     Dragon        125       90     98           5      False
#          Fighting       45      115     58           5      False
#          Fire          110       80     95           2      False
#          Flying        131       98     99           6       True
#          Ghost          65       65     50           3      False
#          Ice            45       85    125           4      False
#          Psychic        68       75     73           6      False
#          Steel          60       70     70           5      False
#          no             60      130     65           2      False
# Dragon   Electric      120      100     90           5       True
#          Fairy         110      105     80           3      False
#          Fire          150      120     90           5       True
#          Flying        180      100    115           3       True
#          Ground        120       95     92           4      False
#          Ice           130       90     95           5       True
#          Psychic       130      110    110           3       True
#          no            110      150     80           6      False
# Electric Dragon        165      110     45           2      False
# ...                    ...      ...    ...         ...        ...
# Rock     Ground         55       65     45           1      False
#          Ice            99       92     58           6      False
#          Psychic        95       85     70           3      False
#          Steel          75      150     40           4      False
#          Water          54       86     68           6      False
#          no             65       50     58           4      False
# Steel    Dragon        150      100     90           4       True
#          Fairy          80       87     75           6      False
#          Fighting       90       72    108           5       True
#          Flying         40       70     70           2      False
#          Ghost          50      150     60           6      False
#          Ground         55       65     30           2      False
#          Psychic       100      100    100           3       True
#          Rock           60       60     50           3      False
#          no             75      150     50           3       True
# Water    Dark           70      130     81           1      False
#          Dragon        150      120    100           4       True
#          Electric       76       76     67           2      False
#          Fairy          60       80     50           2      False
#          Fighting      129       90    108           5      False
#          Flying         60      100     81           1      False
#          Ghost          85      105     60           5      False
#          Grass          90      100     70           3      False
#          Ground         92       82     39           4      False
#          Ice            85       95     60           1      False
#          Poison         80      120    100           1      False
#          Psychic       100      110     30           2      False
#          Rock           45       65     55           3      False
#          Steel         111      101     60           4      False
#          no             90       45     60           3      False
#
# [154 rows x 11 columns]

# %% [markdown]
# ### Exercise 3 - Pump Up The V6
#
# In our quest to find the perfect car to buy, we forgot to analysis the popularity of **no. of cylinders in the car engine** among the various **car manufacturers**. Make a plot that shows us how many companies make a particular `num-of-cylinders` engine. You're free to choose any appropriate plot for this exercise. Don't forget to label and title your plot!

# %%
# TODO: COMPLETE THE BELOW FUNCTION
def plot_cyl_companies(df_cars):
    
    df_cars=df_cars.groupby(['num-of-cylinders'],as_index=False).count()
    df_cars=df_cars.loc[:,['num-of-cylinders','company']]
    
    plt.bar(df_cars['num-of-cylinders'],df_cars['company'])
    plt.xlabel('num-of-cylinders')
    plt.ylabel('company')
    plt.title('popular cylinders')
    
    return df_cars

# %%
# RUN THIS BLOCK TO TEST YOUR CODE
df_cars = pd.read_csv('automobile.csv')
plot_cyl_companies(df_cars)
# Out:
#   num-of-cylinders  company
# 0            eight        3
# 1             five        5
# 2             four       39
# 3              six       11
# 4            three        1
# 5           twelve        1
# 6              two        1

# %% [markdown]
# ### Exercise 4 - Speed v/s Power
#
# Two of your tutors (whose names shall not be revealed) are fighting over which is a more important characteristic to have while choosing a pokémon for battle. You have to resolve this conflict by drawing a plot to compare the distribution of values for the columns `Speed` and `HP` and also, return a tuple containing the overall mean of both columns.

# %%
# TODO: COMPLETE THE BELOW FUNCTION
def poke_conflict_resolution(df_poke):
    
    plt.scatter(df_poke.Speed,df_poke.HP)
    plt.xlabel('speed')
    plt.ylabel('HP')
    
    df_poke=df_pokemon.loc[:,['Speed','HP']].mean().tolist()
    
    return tuple(df_poke)

# %%
# RUN THIS BLOCK TO TEST YOUR CODE
df_pokemon = pd.read_csv('pokemon.csv')
poke_conflict_resolution(df_pokemon)
# Out:
# (68.2775, 69.25875)
